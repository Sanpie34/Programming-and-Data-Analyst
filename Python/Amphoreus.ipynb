# %%
import numpy as np

# %% [markdown]
# # Amphoreus

# %%
Chrysos_Heirs = ["Trailblazer (Sanpie)", "Aglaea", "Tribbie", "Mydei", "Castorice", "Anaxa", "Hyacine", "Cipher",
 "Phainon", "Hysilens", "Cerydra", "Evernight (March 7th)", "Dan Heng Permansor Terrae", "Cyrene"]
Coreflame = ["Passage", "Law", "Time", "Earth", "Ocean", "Sky", "Worldbearing", "Reason", "Romance", "Strife", "Death", "Trickery", "Demiurge", "Trailblaze"]
Month = ["Month of Gate", "Month of Balance", "Month of Evernight", "Month of Cultivation", "Month of Joy", "Month of Everday", "Month of Freedom", "Month of Reaping", "Month of Weaving", "Month of Strife", "Month of Mourning", "Month of Fortune", "-", "-"]
Cycle = 33550337
sum_coreflame = len(Coreflame-2)*Cycle
sum_chrysos_heirs = (len(Chrysos_Heirs-2)*Cycle)+2+2
Antagonist = ["Caenis", "Lygus", "Irontomb"]

# %%
def fight_irontomb():
    irontomb_hp = 1000000000
    irontomb_damage = 1001
    irontomb_skill = np.random.randint(1,11) # Irontomb's skill multiplier ranges from 5 to 15

    trailblazer_hp = 20000
    trailblazer_basic_attack = 150000
    trailblazer_skill = 5000000
    trailblazer_ultimate = 20000000
    skill_point = 5


    Demiurge_help = 13 # Demiurge helps by increasing Trailblazer's damage by 13 times
    Joint_attack = trailblazer_basic_attack + (trailblazer_skill * Demiurge_help)
    Joint_ultimate = sum_coreflame * sum_chrysos_heirs
    
    irontomb_gauge = (irontomb_skill/(irontomb_damage)) # Gauge increase per attack in percentage


def chrysos_heirs_buff()
    Aglaea_buff = action_value * 0.5(1 + speed_value/1000)
    Tribbie_buff = ressistance_value * (-0.8)
    Mydei_buff = crit_rate * 0.75 (total_hp/10000)
    Castorice_buff = attack_value * 0.6 (total_hp/10000)
